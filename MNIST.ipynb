# %%
import numpy as np
import matplotlib.pyplot as plt

import keras

from keras.datasets import mnist

from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
def plot_input_img(i):
    plt.imshow(X_train[i], cmap= 'binary')
    plt.title(y_train[i])
    # plt.axes(False)
    plt.show()

# %%
for i in range(10):
    plot_input_img(i)

# %%
# normalizing the image to [0,1] range
X_train = X_train.astype(np.float32)/255
X_test = X_test.astype(np.float32)/255

# expand the dimensions of image to (28,28,1)
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)

# convert classes to one hot vectors
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# %%
model= Sequential()

model.add(Conv2D(32,(3,3),input_shape = (28,28,1), activation= 'relu'))
model.add(MaxPool2D(2,2))

model.add(Conv2D(64,(3,3), activation= 'relu'))
model.add(MaxPool2D(2,2))

model.add(Flatten())

model.add(Dropout(0.25))

model.add(Dense(10, activation= "softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer= 'adam', loss= keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
# callbacks
from keras.callbacks import EarlyStopping, ModelCheckpoint

# earlystopping
es = EarlyStopping(monitor='val_acc', min_delta = 0.01, patience = 4, verbose=1)

# model check point
# mc = ModelCheckpoint('bestmodel.h5', monitor = 'val_accuracy', verbose = 1, save_best_only = True)
mc = ModelCheckpoint('best_model.h5',monitor = 'val_accuracy', save_best_only=True, mode='max', verbose=1)

cb= [es,mc]

# %% [markdown]
# Model Training

# %%
his = model.fit(X_train, y_train, epochs= 50, validation_split= 0.3, callbacks= cb)
# Out:
# Epoch 1/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.2143 - accuracy: 0.9358WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 1: val_accuracy improved from -inf to 0.97544, saving model to best_model.h5
# 1313/1313 [==============================] - 23s 17ms/step - loss: 0.2142 - accuracy: 0.9358 - val_loss: 0.0811 - val_accuracy: 0.9754
# Epoch 2/50
#    8/1313 [..............................] - ETA: 21s - loss: 0.0654 - accuracy: 0.9766
# c:\Users\pappu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0742 - accuracy: 0.9775WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 2: val_accuracy improved from 0.97544 to 0.97872, saving model to best_model.h5
# 1313/1313 [==============================] - 20s 15ms/step - loss: 0.0743 - accuracy: 0.9775 - val_loss: 0.0676 - val_accuracy: 0.9787
# Epoch 3/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9823WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 3: val_accuracy improved from 0.97872 to 0.98356, saving model to best_model.h5
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0570 - accuracy: 0.9823 - val_loss: 0.0534 - val_accuracy: 0.9836
# Epoch 4/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0465 - accuracy: 0.9849WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 4: val_accuracy improved from 0.98356 to 0.98372, saving model to best_model.h5
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0465 - accuracy: 0.9850 - val_loss: 0.0511 - val_accuracy: 0.9837
# Epoch 5/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9879WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 5: val_accuracy improved from 0.98372 to 0.98489, saving model to best_model.h5
# 1313/1313 [==============================] - 19s 15ms/step - loss: 0.0378 - accuracy: 0.9880 - val_loss: 0.0502 - val_accuracy: 0.9849
# Epoch 6/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9892WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 6: val_accuracy improved from 0.98489 to 0.98728, saving model to best_model.h5
# 1313/1313 [==============================] - 20s 16ms/step - loss: 0.0339 - accuracy: 0.9892 - val_loss: 0.0405 - val_accuracy: 0.9873
# Epoch 7/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0295 - accuracy: 0.9905WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 7: val_accuracy improved from 0.98728 to 0.98811, saving model to best_model.h5
# 1313/1313 [==============================] - 19s 15ms/step - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.0387 - val_accuracy: 0.9881
# Epoch 8/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9916WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 8: val_accuracy did not improve from 0.98811
# 1313/1313 [==============================] - 19s 14ms/step - loss: 0.0260 - accuracy: 0.9916 - val_loss: 0.0405 - val_accuracy: 0.9878
# Epoch 9/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9922WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 9: val_accuracy improved from 0.98811 to 0.98883, saving model to best_model.h5
# 1313/1313 [==============================] - 18s 14ms/step - loss: 0.0233 - accuracy: 0.9922 - val_loss: 0.0380 - val_accuracy: 0.9888
# Epoch 10/50
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9927WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 10: val_accuracy did not improve from 0.98883
# 1313/1313 [==============================] - 18s 14ms/step - loss: 0.0206 - accuracy: 0.9927 - val_loss: 0.0412 - val_accuracy: 0.9888
# Epoch 11/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9936WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 11: val_accuracy did not improve from 0.98883
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0179 - accuracy: 0.9936 - val_loss: 0.0411 - val_accuracy: 0.9881
# Epoch 12/50
# 1308/1313 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 12: val_accuracy improved from 0.98883 to 0.98906, saving model to best_model.h5
# 1313/1313 [==============================] - 18s 14ms/step - loss: 0.0176 - accuracy: 0.9941 - val_loss: 0.0451 - val_accuracy: 0.9891
# Epoch 13/50
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 13: val_accuracy improved from 0.98906 to 0.98989, saving model to best_model.h5
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0384 - val_accuracy: 0.9899
# Epoch 14/50
# 1308/1313 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9946WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 14: val_accuracy improved from 0.98989 to 0.99000, saving model to best_model.h5
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0149 - accuracy: 0.9946 - val_loss: 0.0370 - val_accuracy: 0.9900
# Epoch 15/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9955WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 15: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0442 - val_accuracy: 0.9886
# Epoch 16/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 16: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 15s 11ms/step - loss: 0.0134 - accuracy: 0.9950 - val_loss: 0.0428 - val_accuracy: 0.9894
# Epoch 17/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 17: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.0416 - val_accuracy: 0.9895
# Epoch 18/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 18: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 18s 14ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.0436 - val_accuracy: 0.9897
# Epoch 19/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9965WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 19: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.0406 - val_accuracy: 0.9900
# Epoch 20/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9960WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 20: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 19s 14ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.0482 - val_accuracy: 0.9895
# Epoch 21/50
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 21: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 18s 13ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.0438 - val_accuracy: 0.9895
# Epoch 22/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0096 - accuracy: 0.9968WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 22: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 18s 13ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0548 - val_accuracy: 0.9881
# Epoch 23/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 23: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.0528 - val_accuracy: 0.9882
# Epoch 24/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 24: val_accuracy did not improve from 0.99000
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0490 - val_accuracy: 0.9899
# Epoch 25/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9968WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 25: val_accuracy improved from 0.99000 to 0.99006, saving model to best_model.h5
# 1313/1313 [==============================] - 18s 14ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0447 - val_accuracy: 0.9901
# Epoch 26/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9971WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 26: val_accuracy improved from 0.99006 to 0.99017, saving model to best_model.h5
# 1313/1313 [==============================] - 19s 14ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0469 - val_accuracy: 0.9902
# Epoch 27/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9976WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 27: val_accuracy did not improve from 0.99017
# 1313/1313 [==============================] - 18s 13ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0545 - val_accuracy: 0.9897
# Epoch 28/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 28: val_accuracy improved from 0.99017 to 0.99022, saving model to best_model.h5
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0470 - val_accuracy: 0.9902
# Epoch 29/50
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.0085 - accuracy: 0.9968WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 29: val_accuracy did not improve from 0.99022
# 1313/1313 [==============================] - 18s 13ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.0461 - val_accuracy: 0.9902
# Epoch 30/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 30: val_accuracy did not improve from 0.99022
# 1313/1313 [==============================] - 15s 12ms/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 0.0518 - val_accuracy: 0.9897
# Epoch 31/50
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 31: val_accuracy improved from 0.99022 to 0.99056, saving model to best_model.h5
# 1313/1313 [==============================] - 15s 12ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.0470 - val_accuracy: 0.9906
# Epoch 32/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9976WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 32: val_accuracy did not improve from 0.99056
# 1313/1313 [==============================] - 15s 12ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0488 - val_accuracy: 0.9901
# Epoch 33/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 33: val_accuracy did not improve from 0.99056
# 1313/1313 [==============================] - 15s 12ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0557 - val_accuracy: 0.9892
# Epoch 34/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 34: val_accuracy did not improve from 0.99056
# 1313/1313 [==============================] - 18s 14ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0622 - val_accuracy: 0.9893
# Epoch 35/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9971WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 35: val_accuracy did not improve from 0.99056
# 1313/1313 [==============================] - 18s 14ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0537 - val_accuracy: 0.9896
# Epoch 36/50
# 1308/1313 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9976WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 36: val_accuracy did not improve from 0.99056
# 1313/1313 [==============================] - 20s 15ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0563 - val_accuracy: 0.9890
# Epoch 37/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 37: val_accuracy did not improve from 0.99056
# 1313/1313 [==============================] - 19s 14ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.0496 - val_accuracy: 0.9893
# Epoch 38/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9978WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 38: val_accuracy improved from 0.99056 to 0.99094, saving model to best_model.h5
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0478 - val_accuracy: 0.9909
# Epoch 39/50
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 39: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 18s 14ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0574 - val_accuracy: 0.9901
# Epoch 40/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 40: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 19s 15ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0508 - val_accuracy: 0.9905
# Epoch 41/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9975WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 41: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 18s 14ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0511 - val_accuracy: 0.9901
# Epoch 42/50
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9981WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 42: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0618 - val_accuracy: 0.9890
# Epoch 43/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9985WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 43: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.0649 - val_accuracy: 0.9891
# Epoch 44/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 44: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0578 - val_accuracy: 0.9897
# Epoch 45/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 45: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0627 - val_accuracy: 0.9899
# Epoch 46/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9985WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 46: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0634 - val_accuracy: 0.9893
# Epoch 47/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 47: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0707 - val_accuracy: 0.9891
# Epoch 48/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9981WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 48: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0552 - val_accuracy: 0.9898
# Epoch 49/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 49: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.0622 - val_accuracy: 0.9902
# Epoch 50/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9981WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 50: val_accuracy did not improve from 0.99094
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.0536 - val_accuracy: 0.9909

# %%
model_S = keras.models.load_model('C://Users//pappu//OneDrive//Desktop//projects//ML project//best_model.h5')

# %%
score = model_S.evaluate(X_test, y_test)

print(f'the model accuracy is {score[1]}')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0435 - accuracy: 0.9913
# the model accuracy is 0.9912999868392944
